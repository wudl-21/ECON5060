# %% [markdown]
# # Forecasting US Interest Rate: Regression with Decision Tree

# %% [markdown]
# Keypoints:
# The program is organized by following steps:
# 1. Data import
# 2. Data processing: Translate Non-stationary data into stationary data using the give transformation code. Select the target column which is 'FEDFUNDS',transform the order of the column. Data cleaning : drop some columns and rows without data.
# 3. Feature selection: Use Recursive Feature Elimination (RFE) to select the most relevent feature.(Similar to code sample given by Pro.Ng).
# 4. Optimal hyperparameters: Grid search for optimal features number, module max depth,min split and min leaf number.
# 5. Moduling：Regression with Decision Tree, feature number is 5, max_depth is 3,min_samples_split is 2,min_samples_leaf is 1.
# 6. Performance: The mse between predicted value and actual value is 0.42, not too bad. But there are some problems：1. Underfitting. The predicted value doesn't fit the actual value vary well although the mse is small.(Check the table and two pictures) 2.Computationally expensive. The grid search part cost lots of time to building a decision tree, if there are more feature to check, the time will be so long which also limit the selection of parameters.

# %%
#Standard libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import time
sns.set(style='whitegrid', palette='muted')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 14, 8

#sklearn
from sklearn import metrics
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

from sklearn import linear_model
from sklearn.linear_model import LinearRegression

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

from sklearn.feature_selection import RFE

from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree

# %%
# Imports data
macro = pd.read_csv('US FRED-MD Macro Dataset.csv' ,header=0, index_col=0, parse_dates=True)
macro.shape
# Out:
# (773, 127)

# %%
macro
# Out:
#                   RPI  W875RX1  DPCERA3M086SBEA     CMRMTSPLx       RETAILx  \
# sasdate
# 1959-01-01   2442.158   2293.2           17.272  2.922664e+05   18235.77392
# 1959-01-02   2451.778   2301.5           17.452  2.944247e+05   18369.56308
# 1959-01-03   2467.594   2318.5           17.617  2.934187e+05   18523.05762
# 1959-01-04   2483.671   2334.9           17.553  2.993228e+05   18534.46600
# 1959-01-05   2498.026   2350.4           17.765  3.013643e+05   18679.66354
# ...               ...      ...              ...           ...           ...
# 2023-01-01  17821.000  14623.3          130.028  1.581882e+06  692501.00000
# 2023-01-02  17839.528  14622.7          129.991  1.575290e+06  687942.00000
# 2023-01-03  17885.887  14664.3          129.948  1.560472e+06  681673.00000
# 2023-01-04  17866.773  14659.0          130.255  1.556928e+06  684213.00000
# 2023-01-05  17915.688  14702.7          130.222           NaN  686573.00000
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 1959-01-01   21.9665   23.3891   22.2688   31.7011   19.0149  ...
# 1959-01-02   22.3966   23.7048   22.4617   31.9337   19.1147  ...
# 1959-01-03   22.7193   23.8483   22.5719   31.9337   19.4890  ...
# 1959-01-04   23.2032   24.1927   22.9026   32.4374   19.6138  ...
# 1959-01-05   23.5528   24.3936   23.1231   32.5925   20.0130  ...
# ...              ...       ...       ...       ...       ...  ...
# 2023-01-01  102.5080  101.2863  101.3295  102.0755  104.8646  ...
# 2023-01-02  102.5023  101.0873  101.1983  102.1753  105.0877  ...
# 2023-01-03  102.6521  101.0102  101.1678  102.4580  103.9786  ...
# 2023-01-04  103.1748  101.7373  102.1572  103.4504  108.3743  ...
# 2023-01-05  103.0107  101.6856  102.0669  103.3327  108.7279  ...
#
#             DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# sasdate
# 1959-01-01           17.791           11.326           2.13           2.45
# 1959-01-02           17.798           11.343           2.14           2.46
# 1959-01-03           17.785           11.363           2.15           2.45
# 1959-01-04           17.796           11.403           2.16           2.47
# 1959-01-05           17.777           11.421           2.17           2.48
# ...                     ...              ...            ...            ...
# 2023-01-01          114.885          134.903          28.91          33.44
# 2023-01-02          115.279          135.397          28.98          33.61
# 2023-01-03          114.930          135.782          29.12          33.79
# 2023-01-04          115.341          136.315          29.22          33.92
# 2023-01-05          114.944          136.665          29.36          34.07
#
#             CES3000000008  UMCSENTx  DTCOLNVHFNM   DTCTHFNM     INVEST  \
# sasdate
# 1959-01-01           2.04       NaN      6476.00   12298.00    84.2043
# 1959-01-02           2.05       NaN      6476.00   12298.00    83.5280
# 1959-01-03           2.07       NaN      6508.00   12349.00    81.6405
# 1959-01-04           2.08       NaN      6620.00   12484.00    81.8099
# 1959-01-05           2.08      95.3      6753.00   12646.00    80.7315
# ...                   ...       ...          ...        ...        ...
# 2023-01-01          25.82      64.9    383384.74  720635.04  5505.6964
# 2023-01-02          25.81      67.0    385165.01  718917.35  5491.3981
# 2023-01-03          25.95      62.0    388912.72  719670.11  5366.2449
# 2023-01-04          26.03      63.5    390133.21  720155.25  5250.7099
# 2023-01-05          26.19      59.2          NaN        NaN  5220.8945
#
#             VIXCLSx
# sasdate
# 1959-01-01      NaN
# 1959-01-02      NaN
# 1959-01-03      NaN
# 1959-01-04      NaN
# 1959-01-05      NaN
# ...             ...
# 2023-01-01  20.2269
# 2023-01-02  20.2141
# 2023-01-03  22.0446
# 2023-01-04  17.4930
# 2023-01-05  17.3964
#
# [773 rows x 127 columns]

# %%
# data processing
tran_code = pd.read_csv('Definition_Transformation Code.csv', header=0, index_col=0, parse_dates=False)
tran_code.shape
# Out:
# (1, 127)

# %%
tran_code
# Out:
#        RPI  W875RX1  DPCERA3M086SBEA  CMRMTSPLx  RETAILx  INDPRO  IPFPNSS  \
# fred
# tcode    5        5                5          5        5       5        5
#
#        IPFINAL  IPCONGD  IPDCONGD  ...  DNDGRG3M086SBEA  DSERRG3M086SBEA  \
# fred                               ...
# tcode        5        5         5  ...                6                6
#
#        CES0600000008  CES2000000008  CES3000000008  UMCSENTx  DTCOLNVHFNM  \
# fred
# tcode              6              6              6         2            6
#
#        DTCTHFNM  INVEST  VIXCLSx
# fred
# tcode         6       6        1
#
# [1 rows x 127 columns]

# %%
def data_transform(x, tran_code):
    
    if tran_code == 1:
        x_tr = x        
        
    elif tran_code == 2:
        x_tr = x.diff()
            
    elif tran_code == 3:
        x_tr = x.diff().diff()
        
    elif tran_code == 4:
        x_tr = np.log(x)
        
    elif tran_code == 5:
        x_tr = np.log(x).diff()*100
    
    elif tran_code == 6:
        x_tr = np.log(x).diff().diff()*100
    else :
        x_tr = (x.pct_change()-1)*100
    
    return x_tr

# %%
macro_tr=[]

for col in macro.columns:
    tr_code = tran_code[col].values
    data_tr = data_transform(macro[col], tr_code)
    macro_tr.append(data_tr)

macro_tr = pd.DataFrame(macro_tr).T

# %%
macro_tr
# Out:
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 1959-01-01       NaN       NaN              NaN        NaN       NaN
# 1959-01-02  0.393140  0.361286         1.036756   0.735762  0.730985
# 1959-01-03  0.643011  0.735934         0.941009  -0.342293  0.832120
# 1959-01-04  0.649412  0.704864        -0.363947   1.992210  0.061571
# 1959-01-05  0.576311  0.661646         1.200535   0.679731  0.780340
# ...              ...       ...              ...        ...       ...
# 2023-01-01  0.087570  0.130699         1.316033   0.190398  2.764501
# 2023-01-02  0.103913 -0.004103        -0.028459  -0.417590 -0.660515
# 2023-01-03  0.259530  0.284085        -0.033085  -0.945104 -0.915446
# 2023-01-04 -0.106924 -0.036149         0.235970  -0.227369  0.371920
# 2023-01-05  0.273402  0.297667        -0.025338        NaN  0.344328
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 1959-01-01       NaN       NaN       NaN       NaN       NaN  ...
# 1959-01-02  1.939060  1.340746  0.862504  0.731050  0.523479  ...
# 1959-01-03  1.430562  0.603538  0.489413  0.000000  1.939253  ...
# 1959-01-04  2.107542  1.433800  1.454467  1.565020  0.638320  ...
# 1959-01-05  1.495451  0.826987  0.958168  0.477012  2.014866  ...
# ...              ...       ...       ...       ...       ...  ...
# 2023-01-01  1.003181  0.343776 -0.014901 -0.334291  0.217564  ...
# 2023-01-02 -0.005561 -0.196666 -0.129562  0.097723  0.212525  ...
# 2023-01-03  0.146036 -0.076300 -0.030143  0.276299 -1.061013  ...
# 2023-01-04  0.507904  0.717250  0.973228  0.963931  4.140587  ...
# 2023-01-05 -0.159177 -0.050830 -0.088432 -0.113839  0.325745  ...
#
#             DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# sasdate
# 1959-01-01              NaN              NaN            NaN            NaN
# 1959-01-02              NaN              NaN            NaN            NaN
# 1959-01-03        -0.112407         0.026180      -0.002184      -0.814665
# 1959-01-04         0.134899         0.175237      -0.002163       1.220345
# 1959-01-05        -0.168653        -0.193673      -0.002143      -0.408972
# ...                     ...              ...            ...            ...
# 2023-01-01         1.425376         0.033243       0.170724      -0.004386
# 2023-01-02        -0.416042        -0.224790      -0.417543      -0.152983
# 2023-01-03        -0.645568        -0.081575       0.240091       0.027041
# 2023-01-04         0.660174         0.107827      -0.139110      -0.150135
# 2023-01-05        -0.701762        -0.135343       0.135161       0.057251
#
#             CES3000000008  UMCSENTx  DTCOLNVHFNM  DTCTHFNM    INVEST  VIXCLSx
# sasdate
# 1959-01-01            NaN       NaN          NaN       NaN       NaN      NaN
# 1959-01-02            NaN       NaN          NaN       NaN       NaN      NaN
# 1959-01-03       0.481883       NaN     0.492915  0.413844 -1.479236      NaN
# 1959-01-04      -0.488953       NaN     1.213403  0.673430  2.492924      NaN
# 1959-01-05      -0.481929       NaN     0.282830  0.202040 -1.534223      NaN
# ...                   ...       ...          ...       ...       ...      ...
# 2023-01-01       0.309575       5.2     0.071035  0.049043 -0.142513  20.2269
# 2023-01-02      -0.621376       2.1    -0.237727 -0.068985 -0.121427  20.2141
# 2023-01-03       0.579697      -5.0     0.505030  0.343295 -2.045412  22.0446
# 2023-01-04      -0.233149       1.5    -0.654981 -0.037264  0.128939  17.4930
# 2023-01-05       0.304983      -4.3          NaN       NaN  1.607056  17.3964
#
# [773 rows x 127 columns]

# %%
# Show rows and columns
print("Rows, Columns:");print(macro_tr.shape);print("\n")

# Describe DataFrame columns
print("Columns:");print(macro_tr.columns);print("\n")

# Show info on DataFrame
print("Info:");print(macro_tr.info(max_cols=1000)); print("\n")

# Count Non-NA values
print("Non-NA:");print(macro_tr.count()); print("\n")

# Show head
print("Head");print(macro_tr.head()); print("\n")

# Show tail
print("Tail");print(macro_tr.tail());print("\n")

# Show summary statistics
print("Summary statistics:");print(macro_tr.describe());print("\n")
# Out:
# Rows, Columns:
# (773, 127)
#
#
# Columns:
# Index(['RPI', 'W875RX1', 'DPCERA3M086SBEA', 'CMRMTSPLx', 'RETAILx', 'INDPRO',
#        'IPFPNSS', 'IPFINAL', 'IPCONGD', 'IPDCONGD',
#        ...
#        'DNDGRG3M086SBEA', 'DSERRG3M086SBEA', 'CES0600000008', 'CES2000000008',
#        'CES3000000008', 'UMCSENTx', 'DTCOLNVHFNM', 'DTCTHFNM', 'INVEST',
#        'VIXCLSx'],
#       dtype='object', length=127)
#
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 773 entries, 1959-01-01 to 2023-01-05
# Data columns (total 127 columns):
#  #    Column           Non-Null Count  Dtype
# ---   ------           --------------  -----
#  0    RPI              772 non-null    float64
#  1    W875RX1          772 non-null    float64
#  2    DPCERA3M086SBEA  772 non-null    float64
#  3    CMRMTSPLx        771 non-null    float64
#  4    RETAILx          772 non-null    float64
#  5    INDPRO           772 non-null    float64
#  6    IPFPNSS          772 non-null    float64
#  7    IPFINAL          772 non-null    float64
#  8    IPCONGD          772 non-null    float64
#  9    IPDCONGD         772 non-null    float64
#  10   IPNCONGD         772 non-null    float64
#  11   IPBUSEQ          772 non-null    float64
#  12   IPMAT            772 non-null    float64
#  13   IPDMAT           772 non-null    float64
#  14   IPNMAT           772 non-null    float64
#  15   IPMANSICS        772 non-null    float64
#  16   IPB51222S        772 non-null    float64
#  17   IPFUELS          772 non-null    float64
#  18   CUMFNS           772 non-null    float64
#  19   HWI              771 non-null    float64
#  20   HWIURATIO        771 non-null    float64
#  21   CLF16OV          772 non-null    float64
#  22   CE16OV           772 non-null    float64
#  23   UNRATE           772 non-null    float64
#  24   UEMPMEAN         772 non-null    float64
#  25   UEMPLT5          772 non-null    float64
#  26   UEMP5TO14        772 non-null    float64
#  27   UEMP15OV         772 non-null    float64
#  28   UEMP15T26        772 non-null    float64
#  29   UEMP27OV         772 non-null    float64
#  30   CLAIMSx          772 non-null    float64
#  31   PAYEMS           772 non-null    float64
#  32   USGOOD           772 non-null    float64
#  33   CES1021000001    772 non-null    float64
#  34   USCONS           772 non-null    float64
#  35   MANEMP           772 non-null    float64
#  36   DMANEMP          772 non-null    float64
#  37   NDMANEMP         772 non-null    float64
#  38   SRVPRD           772 non-null    float64
#  39   USTPU            772 non-null    float64
#  40   USWTRADE         772 non-null    float64
#  41   USTRADE          772 non-null    float64
#  42   USFIRE           772 non-null    float64
#  43   USGOVT           772 non-null    float64
#  44   CES0600000007    773 non-null    float64
#  45   AWOTMAN          772 non-null    float64
#  46   AWHMAN           773 non-null    float64
#  47   HOUST            773 non-null    float64
#  48   HOUSTNE          773 non-null    float64
#  49   HOUSTMW          773 non-null    float64
#  50   HOUSTS           773 non-null    float64
#  51   HOUSTW           773 non-null    float64
#  52   PERMIT           761 non-null    float64
#  53   PERMITNE         761 non-null    float64
#  54   PERMITMW         761 non-null    float64
#  55   PERMITS          761 non-null    float64
#  56   PERMITW          761 non-null    float64
#  57   ACOGNO           374 non-null    float64
#  58   AMDMNOx          772 non-null    float64
#  59   ANDENOx          663 non-null    float64
#  60   AMDMUOx          772 non-null    float64
#  61   BUSINVx          771 non-null    float64
#  62   ISRATIOx         771 non-null    float64
#  63   M1SL             771 non-null    float64
#  64   M2SL             771 non-null    float64
#  65   M2REAL           772 non-null    float64
#  66   BOGMBASE         771 non-null    float64
#  67   TOTRESNS         771 non-null    float64
#  68   NONBORRES        772 non-null    float64
#  69   BUSLOANS         771 non-null    float64
#  70   REALLN           771 non-null    float64
#  71   NONREVSL         770 non-null    float64
#  72   CONSPI           771 non-null    float64
#  73   S&P 500          772 non-null    float64
#  74   S&P: indust      772 non-null    float64
#  75   S&P div yield    770 non-null    float64
#  76   S&P PE ratio     771 non-null    float64
#  77   FEDFUNDS         772 non-null    float64
#  78   CP3Mx            770 non-null    float64
#  79   TB3MS            772 non-null    float64
#  80   TB6MS            772 non-null    float64
#  81   GS1              772 non-null    float64
#  82   GS5              772 non-null    float64
#  83   GS10             772 non-null    float64
#  84   AAA              772 non-null    float64
#  85   BAA              772 non-null    float64
#  86   COMPAPFFx        772 non-null    float64
#  87   TB3SMFFM         773 non-null    float64
#  88   TB6SMFFM         773 non-null    float64
#  89   T1YFFM           773 non-null    float64
#  90   T5YFFM           773 non-null    float64
#  91   T10YFFM          773 non-null    float64
#  92   AAAFFM           773 non-null    float64
#  93   BAAFFM           773 non-null    float64
#  94   TWEXAFEGSMTHx    604 non-null    float64
#  95   EXSZUSx          772 non-null    float64
#  96   EXJPUSx          772 non-null    float64
#  97   EXUSUKx          772 non-null    float64
#  98   EXCAUSx          772 non-null    float64
#  99   WPSFD49207       771 non-null    float64
#  100  WPSFD49502       771 non-null    float64
#  101  WPSID61          771 non-null    float64
#  102  WPSID62          771 non-null    float64
#  103  OILPRICEx        771 non-null    float64
#  104  PPICMM           771 non-null    float64
#  105  CPIAUCSL         771 non-null    float64
#  106  CPIAPPSL         771 non-null    float64
#  107  CPITRNSL         771 non-null    float64
#  108  CPIMEDSL         771 non-null    float64
#  109  CUSR0000SAC      771 non-null    float64
#  110  CUSR0000SAD      771 non-null    float64
#  111  CUSR0000SAS      771 non-null    float64
#  112  CPIULFSL         771 non-null    float64
#  113  CUSR0000SA0L2    771 non-null    float64
#  114  CUSR0000SA0L5    771 non-null    float64
#  115  PCEPI            771 non-null    float64
#  116  DDURRG3M086SBEA  771 non-null    float64
#  117  DNDGRG3M086SBEA  771 non-null    float64
#  118  DSERRG3M086SBEA  771 non-null    float64
#  119  CES0600000008    771 non-null    float64
#  120  CES2000000008    771 non-null    float64
#  121  CES3000000008    771 non-null    float64
#  122  UMCSENTx         544 non-null    float64
#  123  DTCOLNVHFNM      770 non-null    float64
#  124  DTCTHFNM         770 non-null    float64
#  125  INVEST           771 non-null    float64
#  126  VIXCLSx          731 non-null    float64
# dtypes: float64(127)
# memory usage: 789.2 KB
# None
#
#
# Non-NA:
# RPI                772
# W875RX1            772
# DPCERA3M086SBEA    772
# CMRMTSPLx          771
# RETAILx            772
#                   ...
# UMCSENTx           544
# DTCOLNVHFNM        770
# DTCTHFNM           770
# INVEST             771
# VIXCLSx            731
# Length: 127, dtype: int64
#
#
# Head
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 1959-01-01       NaN       NaN              NaN        NaN       NaN
# 1959-01-02  0.393140  0.361286         1.036756   0.735762  0.730985
# 1959-01-03  0.643011  0.735934         0.941009  -0.342293  0.832120
# 1959-01-04  0.649412  0.704864        -0.363947   1.992210  0.061571
# 1959-01-05  0.576311  0.661646         1.200535   0.679731  0.780340
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 1959-01-01       NaN       NaN       NaN       NaN       NaN  ...
# 1959-01-02  1.939060  1.340746  0.862504  0.731050  0.523479  ...
# 1959-01-03  1.430562  0.603538  0.489413  0.000000  1.939253  ...
# 1959-01-04  2.107542  1.433800  1.454467  1.565020  0.638320  ...
# 1959-01-05  1.495451  0.826987  0.958168  0.477012  2.014866  ...
#
#             DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# sasdate
# 1959-01-01              NaN              NaN            NaN            NaN
# 1959-01-02              NaN              NaN            NaN            NaN
# 1959-01-03        -0.112407         0.026180      -0.002184      -0.814665
# 1959-01-04         0.134899         0.175237      -0.002163       1.220345
# 1959-01-05        -0.168653        -0.193673      -0.002143      -0.408972
#
#             CES3000000008  UMCSENTx  DTCOLNVHFNM  DTCTHFNM    INVEST  VIXCLSx
# sasdate
# 1959-01-01            NaN       NaN          NaN       NaN       NaN      NaN
# 1959-01-02            NaN       NaN          NaN       NaN       NaN      NaN
# 1959-01-03       0.481883       NaN     0.492915  0.413844 -1.479236      NaN
# 1959-01-04      -0.488953       NaN     1.213403  0.673430  2.492924      NaN
# 1959-01-05      -0.481929       NaN     0.282830  0.202040 -1.534223      NaN
#
# [5 rows x 127 columns]
#
#
# Tail
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 2023-01-01  0.087570  0.130699         1.316033   0.190398  2.764501
# 2023-01-02  0.103913 -0.004103        -0.028459  -0.417590 -0.660515
# 2023-01-03  0.259530  0.284085        -0.033085  -0.945104 -0.915446
# 2023-01-04 -0.106924 -0.036149         0.235970  -0.227369  0.371920
# 2023-01-05  0.273402  0.297667        -0.025338        NaN  0.344328
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 2023-01-01  1.003181  0.343776 -0.014901 -0.334291  0.217564  ...
# 2023-01-02 -0.005561 -0.196666 -0.129562  0.097723  0.212525  ...
# 2023-01-03  0.146036 -0.076300 -0.030143  0.276299 -1.061013  ...
# 2023-01-04  0.507904  0.717250  0.973228  0.963931  4.140587  ...
# 2023-01-05 -0.159177 -0.050830 -0.088432 -0.113839  0.325745  ...
#
#             DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# sasdate
# 2023-01-01         1.425376         0.033243       0.170724      -0.004386
# 2023-01-02        -0.416042        -0.224790      -0.417543      -0.152983
# 2023-01-03        -0.645568        -0.081575       0.240091       0.027041
# 2023-01-04         0.660174         0.107827      -0.139110      -0.150135
# 2023-01-05        -0.701762        -0.135343       0.135161       0.057251
#
#             CES3000000008  UMCSENTx  DTCOLNVHFNM  DTCTHFNM    INVEST  VIXCLSx
# sasdate
# 2023-01-01       0.309575       5.2     0.071035  0.049043 -0.142513  20.2269
# 2023-01-02      -0.621376       2.1    -0.237727 -0.068985 -0.121427  20.2141
# 2023-01-03       0.579697      -5.0     0.505030  0.343295 -2.045412  22.0446
# 2023-01-04      -0.233149       1.5    -0.654981 -0.037264  0.128939  17.4930
# 2023-01-05       0.304983      -4.3          NaN       NaN  1.607056  17.3964
#
# [5 rows x 127 columns]
#
#
# Summary statistics:
#               RPI     W875RX1  DPCERA3M086SBEA   CMRMTSPLx     RETAILx  \
# count  772.000000  772.000000       772.000000  771.000000  772.000000
# mean     0.258134    0.240684         0.261678    0.216966    0.469991
# std      1.183156    0.613966         0.835187    1.267926    1.560335
# min    -14.565065   -6.056840       -12.799379  -12.889057  -15.809242
# 25%      0.057620    0.019656        -0.009627   -0.391493   -0.100021
# 50%      0.273854    0.284552         0.256440    0.220600    0.485266
# 75%      0.479736    0.494470         0.569047    0.843807    1.074441
# max     18.234919    4.012112         8.208242    7.732231   17.405309
#
#            INDPRO     IPFPNSS     IPFINAL     IPCONGD    IPDCONGD  ...  \
# count  772.000000  772.000000  772.000000  772.000000  772.000000  ...
# mean     0.200170    0.190365    0.197207    0.153057    0.225858  ...
# std      1.006339    0.970108    1.062247    1.065949    3.347475  ...
# min    -14.365634  -14.656939  -15.702967  -12.407525  -49.668255  ...
# 25%     -0.172147   -0.226611   -0.245685   -0.348582   -0.820171  ...
# 50%      0.246941    0.236541    0.221127    0.169886    0.292143  ...
# 75%      0.645452    0.646329    0.694881    0.664855    1.332917  ...
# max      6.298618    6.870275    8.287202    8.532604   35.663749  ...
#
#        DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# count       771.000000       771.000000     771.000000     771.000000
# mean         -0.000498         0.000138       0.000012       0.000044
# std           0.622987         0.161782       0.396574       0.894516
# min          -3.736523        -0.944192      -2.950920      -6.807429
# 25%          -0.264319        -0.084273      -0.221739      -0.339970
# 50%           0.002191        -0.007507      -0.001189      -0.002556
# 75%           0.303758         0.079727       0.203186       0.342729
# max           2.767127         1.597500       1.930253       5.305046
#
#        CES3000000008    UMCSENTx  DTCOLNVHFNM    DTCTHFNM      INVEST  \
# count     771.000000  544.000000   770.000000  770.000000  771.000000
# mean        0.000161   -0.045037     0.000407    0.000088    0.000307
# std         0.475667    4.022466     2.366239    1.965352    1.085644
# min        -2.686752  -17.300000   -17.590365  -25.956229   -8.470116
# 25%        -0.243844   -2.400000    -0.682911   -0.397565   -0.588019
# 50%        -0.001110   -0.100000     0.056028    0.055736    0.042164
# 75%         0.218216    2.500000     0.677473    0.488217    0.599093
# max         2.482810   17.300000    18.730787   25.805015    4.994849
#
#           VIXCLSx
# count  731.000000
# mean    19.400722
# std      7.118632
# min      9.484400
# 25%     14.334650
# 50%     17.669500
# 75%     22.588350
# max     62.964800
#
# [8 rows x 127 columns]

# %%
FED = macro_tr['FEDFUNDS']
macro_tr = macro_tr.drop(columns=['FEDFUNDS'])
macro_tr = pd.concat([macro_tr, FED], axis=1)
macro_tr
# Out:
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 1959-01-01       NaN       NaN              NaN        NaN       NaN
# 1959-01-02  0.393140  0.361286         1.036756   0.735762  0.730985
# 1959-01-03  0.643011  0.735934         0.941009  -0.342293  0.832120
# 1959-01-04  0.649412  0.704864        -0.363947   1.992210  0.061571
# 1959-01-05  0.576311  0.661646         1.200535   0.679731  0.780340
# ...              ...       ...              ...        ...       ...
# 2023-01-01  0.087570  0.130699         1.316033   0.190398  2.764501
# 2023-01-02  0.103913 -0.004103        -0.028459  -0.417590 -0.660515
# 2023-01-03  0.259530  0.284085        -0.033085  -0.945104 -0.915446
# 2023-01-04 -0.106924 -0.036149         0.235970  -0.227369  0.371920
# 2023-01-05  0.273402  0.297667        -0.025338        NaN  0.344328
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 1959-01-01       NaN       NaN       NaN       NaN       NaN  ...
# 1959-01-02  1.939060  1.340746  0.862504  0.731050  0.523479  ...
# 1959-01-03  1.430562  0.603538  0.489413  0.000000  1.939253  ...
# 1959-01-04  2.107542  1.433800  1.454467  1.565020  0.638320  ...
# 1959-01-05  1.495451  0.826987  0.958168  0.477012  2.014866  ...
# ...              ...       ...       ...       ...       ...  ...
# 2023-01-01  1.003181  0.343776 -0.014901 -0.334291  0.217564  ...
# 2023-01-02 -0.005561 -0.196666 -0.129562  0.097723  0.212525  ...
# 2023-01-03  0.146036 -0.076300 -0.030143  0.276299 -1.061013  ...
# 2023-01-04  0.507904  0.717250  0.973228  0.963931  4.140587  ...
# 2023-01-05 -0.159177 -0.050830 -0.088432 -0.113839  0.325745  ...
#
#             DSERRG3M086SBEA  CES0600000008  CES2000000008  CES3000000008  \
# sasdate
# 1959-01-01              NaN            NaN            NaN            NaN
# 1959-01-02              NaN            NaN            NaN            NaN
# 1959-01-03         0.026180      -0.002184      -0.814665       0.481883
# 1959-01-04         0.175237      -0.002163       1.220345      -0.488953
# 1959-01-05        -0.193673      -0.002143      -0.408972      -0.481929
# ...                     ...            ...            ...            ...
# 2023-01-01         0.033243       0.170724      -0.004386       0.309575
# 2023-01-02        -0.224790      -0.417543      -0.152983      -0.621376
# 2023-01-03        -0.081575       0.240091       0.027041       0.579697
# 2023-01-04         0.107827      -0.139110      -0.150135      -0.233149
# 2023-01-05        -0.135343       0.135161       0.057251       0.304983
#
#             UMCSENTx  DTCOLNVHFNM  DTCTHFNM    INVEST  VIXCLSx  FEDFUNDS
# sasdate
# 1959-01-01       NaN          NaN       NaN       NaN      NaN       NaN
# 1959-01-02       NaN          NaN       NaN       NaN      NaN     -0.05
# 1959-01-03       NaN     0.492915  0.413844 -1.479236      NaN      0.37
# 1959-01-04       NaN     1.213403  0.673430  2.492924      NaN      0.16
# 1959-01-05       NaN     0.282830  0.202040 -1.534223      NaN     -0.06
# ...              ...          ...       ...       ...      ...       ...
# 2023-01-01       5.2     0.071035  0.049043 -0.142513  20.2269      0.23
# 2023-01-02       2.1    -0.237727 -0.068985 -0.121427  20.2141      0.24
# 2023-01-03      -5.0     0.505030  0.343295 -2.045412  22.0446      0.08
# 2023-01-04       1.5    -0.654981 -0.037264  0.128939  17.4930      0.18
# 2023-01-05      -4.3          NaN       NaN  1.607056  17.3964      0.23
#
# [773 rows x 127 columns]

# %%
#Data cleaning
threshold = 0.05
missing_ratio_c = macro_tr.isnull().mean()
columns_to_drop = missing_ratio_c[missing_ratio_c > threshold].index
macro_tr_cleaned_c = macro_tr.drop(columns=columns_to_drop)
print(columns_to_drop)
# Out:
# Index(['ACOGNO', 'ANDENOx', 'TWEXAFEGSMTHx', 'UMCSENTx', 'VIXCLSx'], dtype='object')

# %%
macro_tr_cleaned_r = macro_tr_cleaned_c.dropna()
macro_tr_cleaned_r.shape
# Out:
# (757, 122)

# %%
 macro_final=macro_tr_cleaned_r
# Show rows and columns
print("Rows, Columns:");print(macro_final.shape);print("\n")

# Describe DataFrame columns
print("Columns:");print(macro_final.columns);print("\n")

# Show info on DataFrame
print("Info:");print(macro_final.info(max_cols=1000)); print("\n")

# Count Non-NA values
print("Non-NA:");print(macro_final.count()); print("\n")

# Show head
print("Head");print(macro_final.head()); print("\n")

# Show tail
print("Tail");print(macro_final.tail());print("\n")

# Show summary statistics
print("Summary statistics:");print(macro_final.describe());print("\n")
# Out:
# Rows, Columns:
# (757, 122)
#
#
# Columns:
# Index(['RPI', 'W875RX1', 'DPCERA3M086SBEA', 'CMRMTSPLx', 'RETAILx', 'INDPRO',
#        'IPFPNSS', 'IPFINAL', 'IPCONGD', 'IPDCONGD',
#        ...
#        'DDURRG3M086SBEA', 'DNDGRG3M086SBEA', 'DSERRG3M086SBEA',
#        'CES0600000008', 'CES2000000008', 'CES3000000008', 'DTCOLNVHFNM',
#        'DTCTHFNM', 'INVEST', 'FEDFUNDS'],
#       dtype='object', length=122)
#
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 757 entries, 1960-01-01 to 2023-01-03
# Data columns (total 122 columns):
#  #    Column           Non-Null Count  Dtype
# ---   ------           --------------  -----
#  0    RPI              757 non-null    float64
#  1    W875RX1          757 non-null    float64
#  2    DPCERA3M086SBEA  757 non-null    float64
#  3    CMRMTSPLx        757 non-null    float64
#  4    RETAILx          757 non-null    float64
#  5    INDPRO           757 non-null    float64
#  6    IPFPNSS          757 non-null    float64
#  7    IPFINAL          757 non-null    float64
#  8    IPCONGD          757 non-null    float64
#  9    IPDCONGD         757 non-null    float64
#  10   IPNCONGD         757 non-null    float64
#  11   IPBUSEQ          757 non-null    float64
#  12   IPMAT            757 non-null    float64
#  13   IPDMAT           757 non-null    float64
#  14   IPNMAT           757 non-null    float64
#  15   IPMANSICS        757 non-null    float64
#  16   IPB51222S        757 non-null    float64
#  17   IPFUELS          757 non-null    float64
#  18   CUMFNS           757 non-null    float64
#  19   HWI              757 non-null    float64
#  20   HWIURATIO        757 non-null    float64
#  21   CLF16OV          757 non-null    float64
#  22   CE16OV           757 non-null    float64
#  23   UNRATE           757 non-null    float64
#  24   UEMPMEAN         757 non-null    float64
#  25   UEMPLT5          757 non-null    float64
#  26   UEMP5TO14        757 non-null    float64
#  27   UEMP15OV         757 non-null    float64
#  28   UEMP15T26        757 non-null    float64
#  29   UEMP27OV         757 non-null    float64
#  30   CLAIMSx          757 non-null    float64
#  31   PAYEMS           757 non-null    float64
#  32   USGOOD           757 non-null    float64
#  33   CES1021000001    757 non-null    float64
#  34   USCONS           757 non-null    float64
#  35   MANEMP           757 non-null    float64
#  36   DMANEMP          757 non-null    float64
#  37   NDMANEMP         757 non-null    float64
#  38   SRVPRD           757 non-null    float64
#  39   USTPU            757 non-null    float64
#  40   USWTRADE         757 non-null    float64
#  41   USTRADE          757 non-null    float64
#  42   USFIRE           757 non-null    float64
#  43   USGOVT           757 non-null    float64
#  44   CES0600000007    757 non-null    float64
#  45   AWOTMAN          757 non-null    float64
#  46   AWHMAN           757 non-null    float64
#  47   HOUST            757 non-null    float64
#  48   HOUSTNE          757 non-null    float64
#  49   HOUSTMW          757 non-null    float64
#  50   HOUSTS           757 non-null    float64
#  51   HOUSTW           757 non-null    float64
#  52   PERMIT           757 non-null    float64
#  53   PERMITNE         757 non-null    float64
#  54   PERMITMW         757 non-null    float64
#  55   PERMITS          757 non-null    float64
#  56   PERMITW          757 non-null    float64
#  57   AMDMNOx          757 non-null    float64
#  58   AMDMUOx          757 non-null    float64
#  59   BUSINVx          757 non-null    float64
#  60   ISRATIOx         757 non-null    float64
#  61   M1SL             757 non-null    float64
#  62   M2SL             757 non-null    float64
#  63   M2REAL           757 non-null    float64
#  64   BOGMBASE         757 non-null    float64
#  65   TOTRESNS         757 non-null    float64
#  66   NONBORRES        757 non-null    float64
#  67   BUSLOANS         757 non-null    float64
#  68   REALLN           757 non-null    float64
#  69   NONREVSL         757 non-null    float64
#  70   CONSPI           757 non-null    float64
#  71   S&P 500          757 non-null    float64
#  72   S&P: indust      757 non-null    float64
#  73   S&P div yield    757 non-null    float64
#  74   S&P PE ratio     757 non-null    float64
#  75   CP3Mx            757 non-null    float64
#  76   TB3MS            757 non-null    float64
#  77   TB6MS            757 non-null    float64
#  78   GS1              757 non-null    float64
#  79   GS5              757 non-null    float64
#  80   GS10             757 non-null    float64
#  81   AAA              757 non-null    float64
#  82   BAA              757 non-null    float64
#  83   COMPAPFFx        757 non-null    float64
#  84   TB3SMFFM         757 non-null    float64
#  85   TB6SMFFM         757 non-null    float64
#  86   T1YFFM           757 non-null    float64
#  87   T5YFFM           757 non-null    float64
#  88   T10YFFM          757 non-null    float64
#  89   AAAFFM           757 non-null    float64
#  90   BAAFFM           757 non-null    float64
#  91   EXSZUSx          757 non-null    float64
#  92   EXJPUSx          757 non-null    float64
#  93   EXUSUKx          757 non-null    float64
#  94   EXCAUSx          757 non-null    float64
#  95   WPSFD49207       757 non-null    float64
#  96   WPSFD49502       757 non-null    float64
#  97   WPSID61          757 non-null    float64
#  98   WPSID62          757 non-null    float64
#  99   OILPRICEx        757 non-null    float64
#  100  PPICMM           757 non-null    float64
#  101  CPIAUCSL         757 non-null    float64
#  102  CPIAPPSL         757 non-null    float64
#  103  CPITRNSL         757 non-null    float64
#  104  CPIMEDSL         757 non-null    float64
#  105  CUSR0000SAC      757 non-null    float64
#  106  CUSR0000SAD      757 non-null    float64
#  107  CUSR0000SAS      757 non-null    float64
#  108  CPIULFSL         757 non-null    float64
#  109  CUSR0000SA0L2    757 non-null    float64
#  110  CUSR0000SA0L5    757 non-null    float64
#  111  PCEPI            757 non-null    float64
#  112  DDURRG3M086SBEA  757 non-null    float64
#  113  DNDGRG3M086SBEA  757 non-null    float64
#  114  DSERRG3M086SBEA  757 non-null    float64
#  115  CES0600000008    757 non-null    float64
#  116  CES2000000008    757 non-null    float64
#  117  CES3000000008    757 non-null    float64
#  118  DTCOLNVHFNM      757 non-null    float64
#  119  DTCTHFNM         757 non-null    float64
#  120  INVEST           757 non-null    float64
#  121  FEDFUNDS         757 non-null    float64
# dtypes: float64(122)
# memory usage: 727.4 KB
# None
#
#
# Non-NA:
# RPI                757
# W875RX1            757
# DPCERA3M086SBEA    757
# CMRMTSPLx          757
# RETAILx            757
#                   ...
# CES3000000008      757
# DTCOLNVHFNM        757
# DTCTHFNM           757
# INVEST             757
# FEDFUNDS           757
# Length: 122, dtype: int64
#
#
# Head
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 1960-01-01  0.319409  0.463825         0.278847   1.695646  2.660551
# 1960-01-02  0.114254  0.091674         0.433454   1.437148  0.369645
# 1960-01-03  0.190876  0.091590         1.404092  -2.802612 -0.110199
# 1960-01-04  0.341874  0.361379         1.535528   0.982647  2.590339
# 1960-01-05  0.240054  0.244332        -2.034337  -3.153052 -1.504683
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD   IPDCONGD  ...  \
# sasdate                                                        ...
# 1960-01-01  2.591713  2.409495  2.902087  3.123538  10.383083  ...
# 1960-01-02 -0.893885 -0.568540 -0.343503 -1.145653  -1.385485  ...
# 1960-01-03 -0.901948 -0.342682 -0.115042  0.115277  -1.996461  ...
# 1960-01-04 -0.795880  0.228983  0.115042  0.687998  -0.118913  ...
# 1960-01-05 -0.114277  0.568790  0.686244  0.569884   0.945486  ...
#
#             DDURRG3M086SBEA  DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  \
# sasdate
# 1960-01-01        -0.259079        -0.178584        -0.128845      -0.468036
# 1960-01-02         0.376462         0.167438         0.085463      -0.455545
# 1960-01-03        -0.455511         0.178561        -0.111313      -0.002011
# 1960-01-04         0.411911         0.443860         0.145034      -0.894856
# 1960-01-05        -0.129782        -0.672338         0.059133       0.894856
#
#             CES2000000008  CES3000000008  DTCOLNVHFNM  DTCTHFNM    INVEST  \
# sasdate
# 1960-01-01       0.779728      -0.970531     0.429236 -1.173886 -1.333027
# 1960-01-02       0.385334      -0.475018     0.826845  0.538766 -1.894229
# 1960-01-03       3.013134      -0.468385     0.347209  0.095090  0.348999
# 1960-01-04      -6.807429       0.000000     0.867818  0.545173  2.413598
# 1960-01-05       4.161967       0.000000    -0.482728 -0.206712  0.379810
#
#             FEDFUNDS
# sasdate
# 1960-01-01      0.00
# 1960-01-02     -0.02
# 1960-01-03     -0.13
# 1960-01-04      0.08
# 1960-01-05     -0.07
#
# [5 rows x 122 columns]
#
#
# Tail
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 2022-01-11  0.000898 -0.075962        -0.414455  -0.947270 -1.320097
# 2022-01-12 -0.013781 -0.019171        -0.193846   1.490076 -0.719328
# 2023-01-01  0.087570  0.130699         1.316033   0.190398  2.764501
# 2023-01-02  0.103913 -0.004103        -0.028459  -0.417590 -0.660515
# 2023-01-03  0.259530  0.284085        -0.033085  -0.945104 -0.915446
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# sasdate                                                       ...
# 2022-01-11 -0.330005 -0.332552 -0.400833 -0.179349 -2.240469  ...
# 2022-01-12 -1.550613 -1.202485 -0.846966 -0.623823 -1.031771  ...
# 2023-01-01  1.003181  0.343776 -0.014901 -0.334291  0.217564  ...
# 2023-01-02 -0.005561 -0.196666 -0.129562  0.097723  0.212525  ...
# 2023-01-03  0.146036 -0.076300 -0.030143  0.276299 -1.061013  ...
#
#             DDURRG3M086SBEA  DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  \
# sasdate
# 2022-01-11        -0.174864        -0.884680        -0.056635       0.102595
# 2022-01-12         0.344041        -0.613838         0.175427      -0.107940
# 2023-01-01         0.474433         1.425376         0.033243       0.170724
# 2023-01-02        -0.436099        -0.416042        -0.224790      -0.417543
# 2023-01-03         0.100107        -0.645568        -0.081575       0.240091
#
#             CES2000000008  CES3000000008  DTCOLNVHFNM  DTCTHFNM    INVEST  \
# sasdate
# 2022-01-11      -0.062401       0.389154     0.162379 -0.007056  0.959749
# 2022-01-12       0.300155      -0.590025    -0.283245 -0.123254  0.880929
# 2023-01-01      -0.004386       0.309575     0.071035  0.049043 -0.142513
# 2023-01-02      -0.152983      -0.621376    -0.237727 -0.068985 -0.121427
# 2023-01-03       0.027041       0.579697     0.505030  0.343295 -2.045412
#
#             FEDFUNDS
# sasdate
# 2022-01-11      0.70
# 2022-01-12      0.32
# 2023-01-01      0.23
# 2023-01-02      0.24
# 2023-01-03      0.08
#
# [5 rows x 122 columns]
#
#
# Summary statistics:
#               RPI     W875RX1  DPCERA3M086SBEA   CMRMTSPLx     RETAILx  \
# count  757.000000  757.000000       757.000000  757.000000  757.000000
# mean     0.247952    0.244962         0.267888    0.225525    0.475994
# std      1.108090    0.570201         0.629362    1.112302    1.316519
# min    -14.565065   -6.056840        -6.629144   -4.105711   -9.426401
# 25%      0.058339    0.021580        -0.006916   -0.395762   -0.097743
# 50%      0.273676    0.283906         0.256442    0.220600    0.485556
# 75%      0.475388    0.493178         0.567651    0.843088    1.089146
# max     18.234919    4.012112         5.617031    7.682370   10.371336
#
#            INDPRO     IPFPNSS     IPFINAL     IPCONGD    IPDCONGD  ...  \
# count  757.000000  757.000000  757.000000  757.000000  757.000000  ...
# mean     0.211312    0.200276    0.208144    0.160660    0.260731  ...
# std      0.814498    0.794337    0.879573    0.949777    2.679016  ...
# min     -4.479030   -4.981219   -5.285651   -5.066252  -18.210554  ...
# 25%     -0.171491   -0.223600   -0.245339   -0.346282   -0.815965  ...
# 50%      0.245977    0.230642    0.215506    0.169931    0.275077  ...
# 75%      0.640684    0.641716    0.688608    0.661989    1.324768  ...
# max      6.298618    6.870275    8.287202    8.532604   35.663749  ...
#
#        DDURRG3M086SBEA  DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  \
# count       757.000000       757.000000       757.000000     757.000000
# mean         -0.000631        -0.001262        -0.000219      -0.001804
# std           0.327726         0.626633         0.160715       0.394978
# min          -1.437389        -3.736523        -0.944192      -2.950920
# 25%          -0.179149        -0.265572        -0.084616      -0.222800
# 50%          -0.003245         0.002191        -0.007507      -0.001197
# 75%           0.181205         0.304412         0.079669       0.204078
# max           1.341784         2.767127         1.597500       1.930253
#
#        CES2000000008  CES3000000008  DTCOLNVHFNM    DTCTHFNM      INVEST  \
# count     757.000000     757.000000   757.000000  757.000000  757.000000
# mean        0.000214      -0.001753    -0.000366   -0.002767   -0.000585
# std         0.894919       0.467047     2.383786    1.980928    1.068782
# min        -6.807429      -2.686752   -17.590365  -25.956229   -8.470116
# 25%        -0.329316      -0.239021    -0.690218   -0.405015   -0.580070
# 50%        -0.002530      -0.001110     0.057214    0.056104    0.041852
# 75%         0.340843       0.213395     0.681163    0.488087    0.566340
# max         5.305046       2.482810    18.730787   25.805015    4.994849
#
#          FEDFUNDS
# count  757.000000
# mean     0.001664
# std      0.504902
# min     -6.630000
# 25%     -0.080000
# 50%      0.010000
# 75%      0.120000
# max      3.060000
#
# [8 rows x 122 columns]

# %%
#Define Data for Machine Learning
X_start = 0
X_lag = 1

# Features and Target
X, y = macro_final.iloc[X_start:,:-1].shift(X_lag).dropna(), macro_final.iloc[X_start+X_lag:,121]

# %%
X
# Out:
#                  RPI   W875RX1  DPCERA3M086SBEA  CMRMTSPLx   RETAILx  \
# sasdate
# 1960-01-02  0.319409  0.463825         0.278847   1.695646  2.660551
# 1960-01-03  0.114254  0.091674         0.433454   1.437148  0.369645
# 1960-01-04  0.190876  0.091590         1.404092  -2.802612 -0.110199
# 1960-01-05  0.341874  0.361379         1.535528   0.982647  2.590339
# 1960-01-06  0.240054  0.244332        -2.034337  -3.153052 -1.504683
# ...              ...       ...              ...        ...       ...
# 2022-01-11  0.129404 -0.239825         0.265240  -0.106164  1.039717
# 2022-01-12  0.000898 -0.075962        -0.414455  -0.947270 -1.320097
# 2023-01-01 -0.013781 -0.019171        -0.193846   1.490076 -0.719328
# 2023-01-02  0.087570  0.130699         1.316033   0.190398  2.764501
# 2023-01-03  0.103913 -0.004103        -0.028459  -0.417590 -0.660515
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD   IPDCONGD  ...     PCEPI  \
# sasdate                                                        ...
# 1960-01-02  2.591713  2.409495  2.902087  3.123538  10.383083  ... -0.171620
# 1960-01-03 -0.893885 -0.568540 -0.343503 -1.145653  -1.385485  ...  0.159303
# 1960-01-04 -0.901948 -0.342682 -0.115042  0.115277  -1.996461  ... -0.049056
# 1960-01-05 -0.795880  0.228983  0.115042  0.687998  -0.118913  ...  0.311430
# 1960-01-06 -0.114277  0.568790  0.686244  0.569884   0.945486  ... -0.262920
# ...              ...       ...       ...       ...        ...  ...       ...
# 2022-01-11 -0.112980  0.242440  0.427547  0.515647   1.338680  ...  0.075852
# 2022-01-12 -0.330005 -0.332552 -0.400833 -0.179349  -2.240469  ... -0.248867
# 2023-01-01 -1.550613 -1.202485 -0.846966 -0.623823  -1.031771  ...  0.030879
# 2023-01-02  1.003181  0.343776 -0.014901 -0.334291   0.217564  ...  0.382455
# 2023-01-03 -0.005561 -0.196666 -0.129562  0.097723   0.212525  ... -0.293685
#
#             DDURRG3M086SBEA  DNDGRG3M086SBEA  DSERRG3M086SBEA  CES0600000008  \
# sasdate
# 1960-01-02        -0.259079        -0.178584        -0.128845      -0.468036
# 1960-01-03         0.376462         0.167438         0.085463      -0.455545
# 1960-01-04        -0.455511         0.178561        -0.111313      -0.002011
# 1960-01-05         0.411911         0.443860         0.145034      -0.894856
# 1960-01-06        -0.129782        -0.672338         0.059133       0.894856
# ...                     ...              ...              ...            ...
# 2022-01-11        -0.838316         1.249500        -0.134901       0.033090
# 2022-01-12        -0.174864        -0.884680        -0.056635       0.102595
# 2023-01-01         0.344041        -0.613838         0.175427      -0.107940
# 2023-01-02         0.474433         1.425376         0.033243       0.170724
# 2023-01-03        -0.436099        -0.416042        -0.224790      -0.417543
#
#             CES2000000008  CES3000000008  DTCOLNVHFNM  DTCTHFNM    INVEST
# sasdate
# 1960-01-02       0.779728      -0.970531     0.429236 -1.173886 -1.333027
# 1960-01-03       0.385334      -0.475018     0.826845  0.538766 -1.894229
# 1960-01-04       3.013134      -0.468385     0.347209  0.095090  0.348999
# 1960-01-05      -6.807429       0.000000     0.867818  0.545173  2.413598
# 1960-01-06       4.161967       0.000000    -0.482728 -0.206712  0.379810
# ...                   ...            ...          ...       ...       ...
# 2022-01-11      -0.155321       0.037512     0.034115  0.214359 -0.438250
# 2022-01-12      -0.062401       0.389154     0.162379 -0.007056  0.959749
# 2023-01-01       0.300155      -0.590025    -0.283245 -0.123254  0.880929
# 2023-01-02      -0.004386       0.309575     0.071035  0.049043 -0.142513
# 2023-01-03      -0.152983      -0.621376    -0.237727 -0.068985 -0.121427
#
# [756 rows x 121 columns]

# %%
y
# Out:
# sasdate
# 1960-01-02   -0.02
# 1960-01-03   -0.13
# 1960-01-04    0.08
# 1960-01-05   -0.07
# 1960-01-06   -0.53
#               ...
# 2022-01-11    0.70
# 2022-01-12    0.32
# 2023-01-01    0.23
# 2023-01-02    0.24
# 2023-01-03    0.08
# Name: FEDFUNDS, Length: 756, dtype: float64

# %% [markdown]
# #Feature Selection: Recursive Feature Elimination

# %%
ols = LinearRegression()
model_rfe = RFE(ols, n_features_to_select=10)
model_rfe = model_rfe.fit(X, y)

# %%
rfe = model_rfe.support_
rfe
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False,  True, False, False, False, False,  True,  True, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %%
#Identifying the selected features

rfe_features = []

for i in range(0,rfe.shape[0]):
    if rfe[i] == True:
        rfe_feature = X.columns[i]
        rfe_features.append(rfe_feature)
    
rfe_features
# Out:
# ['HWIURATIO',
#  'MANEMP',
#  'DMANEMP',
#  'NDMANEMP',
#  'ISRATIOx',
#  'CONSPI',
#  'S&P div yield',
#  'GS1',
#  'GS5',
#  'AAA']

# %% [markdown]
# #Define Training,Validation,and Test Sets

# %%
train_pct=0.7
valid_pct=0.15
test_pct=0.15

n_train=int(train_pct*len(X))
n_valid=int(valid_pct*len(X))
n_test=len(X)-n_train-n_valid

print(n_train,n_valid,n_test)
# Out:
# 529 113 114

# %% [markdown]
# #Grid Search for Optimal Hypermeters

# %%
# pipeline
def pipeline(config):

    # unpack config
    n_depth, n_split, n_leaf, n_features = config

    # Steps
    steps = [('rfe', RFE(LinearRegression(), n_features_to_select=n_features)),
             ('dtr', DecisionTreeRegressor(max_depth=n_depth,min_samples_split=n_split,min_samples_leaf=n_leaf))
            ]

    pipeline = Pipeline(steps)

    return pipeline

# %%
def walk_forward_validation(cfg):
    
    n_trains = n_train

    n_records = n_train + n_valid

    y_test_list = []
    
    y_pred_list = []

    j = 0

    for i in range(n_trains, n_records):
    
        X_train, X_test, y_train, y_test = X[j:i], X[i:i+1], y[j:i], y[i:i+1]
       
        model = pipeline(cfg).fit(X_train, y_train)        
    
        y_pred = model.predict(X_test)
    
        y_pred_list.extend(y_pred)
    
        y_test_list.extend(y_test)

        j += 1
    
    score_rmse = metrics.mean_squared_error(y_test_list, y_pred_list,)
    
    print(' > %.3f' % score_rmse)
    
    return score_rmse

# %%
# score a model, return None on failure
def repeat_evaluate(config, n_repeats=1):
    # convert config to a key
    key = str(config)
    # fit and evaluate the model n times
    scores = [walk_forward_validation(config) for _ in range(n_repeats)]
    # summarize score
    result = np.mean(scores)
    print('> Model[%s] %.3f' % (key, result))
    return (key, result)

# %%
# grid search configs
def grid_search(cfg_list):
    # evaluate configs
    scores = [repeat_evaluate(cfg) for cfg in cfg_list]
    # sort configs by score_rmse, asc
    #scores.sort(key=lambda tup: tup[1])
    scores.sort(key=lambda tup: tup[1], reverse=True)
    return scores

# %%
# create a list of configs to try
def model_configs():
    # define scope of configs

    n_depth=[3,5]
    n_split=[2,5]
    n_leaf=[1,2]
    n_features = [5,10]

    #n_features = [10]
     
    # create configs
    configs = list()
    
    for k in n_depth:
        for l in n_split:
            for m in n_leaf:
                for n in n_features:
                    cfg = [k,l,m,n]
                    configs.append(cfg)

    print('Total configs: %d' % len(configs))
    return configs

# %%
# model configs
cfg_list = model_configs()
# Out:
# Total configs: 16

# %%
# grid search
scores = grid_search(cfg_list)
print('done')
# Out:
#  > 0.034
# > Model[[3, 2, 1, 5]] 0.034
#  > 0.038
# > Model[[3, 2, 1, 10]] 0.038
#  > 0.036
# > Model[[3, 2, 2, 5]] 0.036
#  > 0.039
# > Model[[3, 2, 2, 10]] 0.039
#  > 0.034
# > Model[[3, 5, 1, 5]] 0.034
#  > 0.038
# > Model[[3, 5, 1, 10]] 0.038
#  > 0.036
# > Model[[3, 5, 2, 5]] 0.036
#  > 0.039
# > Model[[3, 5, 2, 10]] 0.039
#  > 0.062
# > Model[[5, 2, 1, 5]] 0.062
#  > 0.043
# > Model[[5, 2, 1, 10]] 0.043
#  > 0.109
# > Model[[5, 2, 2, 5]] 0.109
#  > 0.099
# > Model[[5, 2, 2, 10]] 0.099
#  > 0.062
# > Model[[5, 5, 1, 5]] 0.062
#  > 0.043
# > Model[[5, 5, 1, 10]] 0.043
#  > 0.116
# > Model[[5, 5, 2, 5]] 0.116

# %%
scores

# %%
# Model Estimation & Evaluation

# %%
# Pipeline

# Steps
steps_final = [('rfe', RFE(LinearRegression(), n_features_to_select=5)),
               ('dtr', DecisionTreeRegressor(max_depth=3,min_samples_split=2,min_samples_leaf=1))
            ]

pipeline_final = Pipeline(steps_final)

# %%
X_train, X_valid, X_test = X[:n_train], X[n_train:n_train+n_valid], X[n_train+n_valid:n_train+n_valid+n_test]
y_train, y_valid, y_test = y[:n_train], y[n_train:n_train+n_valid], y[n_train+n_valid:n_train+n_valid+n_test]

pipeline_final.fit(X_train, y_train)

# %% [markdown]
# #Performance

# %%
y_pred = pipeline_final.predict(X_test)

# %%
mse = metrics.mean_squared_error(y_test, y_pred)
mse

# %%
pd.options.display.max_rows=300
result = pd.DataFrame({'Interest_rate_Actual': y[-n_test:], 'Interest_rate_Predicted': y_pred}, columns=['Interest_rate_Actual', 'Interest_rate_Predicted'])
result

# %%
result['Interest_rate_Actual'].plot(legend=True)
result['Interest_rate_Predicted'].plot(legend=True)

# %%
plt.scatter(y_test, y_pred)
plt.plot(y_test, y_test,'k-')

# %% [markdown]
# #Reference:
# 1.Scikit-learn developers. (2023). Decision Tree Regression. In Scikit-learn Documentation. Retrieved from https://scikit-learn.org/stable/modules/tree.html#regression
